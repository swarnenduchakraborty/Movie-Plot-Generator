# %%
# !pip install -U ipykernel
# !pip install torch transformers[torch] datasets pandas matplotlib scikit-learn
# Out:
# Requirement already satisfied: ipykernel in d:\gen ai\my first llm\.venv\lib\site-packages (6.29.5)
# Requirement already satisfied: comm>=0.1.1 in d:\gen ai\my first llm\.venv\lib\site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in d:\gen ai\my first llm\.venv\lib\site-packages (from ipykernel) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in d:\gen ai\my first llm\.venv\lib\site-packages (from ipykernel) (9.1.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\gen ai\my first llm\.venv\lib\site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\gen ai\my first llm\.venv\lib\site-packages (from ipykernel) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\gen ai\my first llm\.venv\lib\site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio in d:\gen ai\my first llm\.venv\lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in d:\gen ai\my first llm\.venv\lib\site-packages (from ipykernel) (24.2)
# Requirement already satisfied: psutil in d:\gen ai\my first llm\.venv\lib\site-packages (from ipykernel) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in d:\gen ai\my first llm\.venv\lib\site-packages (from ipykernel) (26.4.0)
# Requirement already satisfied: tornado>=6.1 in d:\gen ai\my first llm\.venv\lib\site-packages (from ipykernel) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: colorama in d:\gen ai\my first llm\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator in d:\gen ai\my first llm\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in d:\gen ai\my first llm\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\gen ai\my first llm\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\gen ai\my first llm\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.19.1)
# Requirement already satisfied: stack_data in d:\gen ai\my first llm\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\gen ai\my first llm\.venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in d:\gen ai\my first llm\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.7)
# Requirement already satisfied: pywin32>=300 in d:\gen ai\my first llm\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (310)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\gen ai\my first llm\.venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: wcwidth in d:\gen ai\my first llm\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: six>=1.5 in d:\gen ai\my first llm\.venv\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in d:\gen ai\my first llm\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Requirement already satisfied: torch in d:\gen ai\my first llm\.venv\lib\site-packages (2.6.0)
# Requirement already satisfied: datasets in d:\gen ai\my first llm\.venv\lib\site-packages (3.5.0)
# Requirement already satisfied: pandas in d:\gen ai\my first llm\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in d:\gen ai\my first llm\.venv\lib\site-packages (3.10.1)
# Requirement already satisfied: scikit-learn in d:\gen ai\my first llm\.venv\lib\site-packages (1.6.1)
# Requirement already satisfied: transformers[torch] in d:\gen ai\my first llm\.venv\lib\site-packages (4.51.3)
# Requirement already satisfied: filelock in d:\gen ai\my first llm\.venv\lib\site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in d:\gen ai\my first llm\.venv\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in d:\gen ai\my first llm\.venv\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in d:\gen ai\my first llm\.venv\lib\site-packages (from torch) (2024.12.0)
# Requirement already satisfied: setuptools in d:\gen ai\my first llm\.venv\lib\site-packages (from torch) (78.1.0)
# Requirement already satisfied: sympy==1.13.1 in d:\gen ai\my first llm\.venv\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from transformers[torch]) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in d:\gen ai\my first llm\.venv\lib\site-packages (from transformers[torch]) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from transformers[torch]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\gen ai\my first llm\.venv\lib\site-packages (from transformers[torch]) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in d:\gen ai\my first llm\.venv\lib\site-packages (from transformers[torch]) (2024.11.6)
# Requirement already satisfied: requests in d:\gen ai\my first llm\.venv\lib\site-packages (from transformers[torch]) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in d:\gen ai\my first llm\.venv\lib\site-packages (from transformers[torch]) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in d:\gen ai\my first llm\.venv\lib\site-packages (from transformers[torch]) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in d:\gen ai\my first llm\.venv\lib\site-packages (from transformers[torch]) (4.67.1)
# Requirement already satisfied: accelerate>=0.26.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from transformers[torch]) (1.6.0)
# Requirement already satisfied: pyarrow>=15.0.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from datasets) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: xxhash in d:\gen ai\my first llm\.venv\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in d:\gen ai\my first llm\.venv\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp in d:\gen ai\my first llm\.venv\lib\site-packages (from datasets) (3.11.16)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\gen ai\my first llm\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\gen ai\my first llm\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\gen ai\my first llm\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\gen ai\my first llm\.venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\gen ai\my first llm\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\gen ai\my first llm\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in d:\gen ai\my first llm\.venv\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\gen ai\my first llm\.venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy>=1.6.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: psutil in d:\gen ai\my first llm\.venv\lib\site-packages (from accelerate>=0.26.0->transformers[torch]) (7.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\gen ai\my first llm\.venv\lib\site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\gen ai\my first llm\.venv\lib\site-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\gen ai\my first llm\.venv\lib\site-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: six>=1.5 in d:\gen ai\my first llm\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\gen ai\my first llm\.venv\lib\site-packages (from requests->transformers[torch]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\gen ai\my first llm\.venv\lib\site-packages (from requests->transformers[torch]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\gen ai\my first llm\.venv\lib\site-packages (from requests->transformers[torch]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\gen ai\my first llm\.venv\lib\site-packages (from requests->transformers[torch]) (2025.1.31)
# Requirement already satisfied: colorama in d:\gen ai\my first llm\.venv\lib\site-packages (from tqdm>=4.27->transformers[torch]) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from jinja2->torch) (3.0.2)

# %%
model_name = "distilgpt2"
device = "cpu"

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained(model_name)

tokenizer.pad_token = tokenizer.eos_token
model = AutoModelForCausalLM.from_pretrained(model_name)

model
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-5): 6 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D(nf=2304, nx=768)
#           (c_proj): Conv1D(nf=768, nx=768)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D(nf=3072, nx=768)
#           (c_proj): Conv1D(nf=768, nx=3072)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
import pandas as pd

df= pd.read_csv("D:\GEN AI\my first llm\movie-plots.csv")
df
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\G'
# <>:3: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\banku\AppData\Local\Temp\ipykernel_19256\609393594.py:3: SyntaxWarning: invalid escape sequence '\G'
#   df= pd.read_csv("D:\GEN AI\my first llm\movie-plots.csv")
#        Release Year                             Title Origin/Ethnicity  \
# 0              1901            Kansas Saloon Smashers         American
# 1              1901     Love by the Light of the Moon         American
# 2              1901           The Martyred Presidents         American
# 3              1901  Terrible Teddy, the Grizzly King         American
# 4              1902            Jack and the Beanstalk         American
# ...             ...                               ...              ...
# 34881          2014                 The Water Diviner          Turkish
# 34882          2017                Çalgı Çengi İkimiz          Turkish
# 34883          2017                      Olanlar Oldu          Turkish
# 34884          2017                  Non-Transferable          Turkish
# 34885          2017                İstanbul Kırmızısı          Turkish
#
#                                  Director  \
# 0                                 Unknown
# 1                                 Unknown
# 2                                 Unknown
# 3                                 Unknown
# 4      George S. Fleming, Edwin S. Porter
# ...                                   ...
# 34881             Director: Russell Crowe
# 34882                      Selçuk Aydemir
# 34883                         Hakan Algül
# 34884                     Brendan Bradley
# 34885                      Ferzan Özpetek
#
#                                                     Cast            Genre  \
# 0                                                    NaN          unknown
# 1                                                    NaN          unknown
# 2                                                    NaN          unknown
# 3                                                    NaN          unknown
# 4                                                    NaN          unknown
# ...                                                  ...              ...
# 34881  Director: Russell Crowe\r\nCast: Russell Crowe...          unknown
# 34882                          Ahmet Kural, Murat Cemcir           comedy
# 34883              Ata Demirer, Tuvana Türkay, Ülkü Duru           comedy
# 34884  YouTubers Shanna Malcolm, Shira Lazar, Sara Fl...  romantic comedy
# 34885  Halit Ergenç, Tuba Büyüküstün, Mehmet Günsür, ...         romantic
#
#                                                Wiki Page  \
# 0      https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1      https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2      https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3      https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4      https://en.wikipedia.org/wiki/Jack_and_the_Bea...
# ...                                                  ...
# 34881    https://en.wikipedia.org/wiki/The_Water_Diviner
# 34882  https://en.wikipedia.org/wiki/%C3%87alg%C4%B1_...
# 34883         https://en.wikipedia.org/wiki/Olanlar_Oldu
# 34884  https://en.wikipedia.org/wiki/Non-Transferable...
# 34885  https://en.wikipedia.org/wiki/%C4%B0stanbul_K%...
#
#                                                     Plot
# 0      A bartender is working at a saloon, serving dr...
# 1      The moon, painted with a smiling face hangs ov...
# 2      The film, just over a minute long, is composed...
# 3      Lasting just 61 seconds and consisting of two ...
# 4      The earliest known adaptation of the classic f...
# ...                                                  ...
# 34881  The film begins in 1919, just after World War ...
# 34882  Two musicians, Salih and Gürkan, described the...
# 34883  Zafer, a sailor living with his mother Döndü i...
# 34884  The film centres around a young woman named Am...
# 34885  The writer Orhan Şahin returns to İstanbul aft...
#
# [34886 rows x 8 columns]

# %%
df =df[:1000]
df
# Out:
#      Release Year                             Title Origin/Ethnicity  \
# 0            1901            Kansas Saloon Smashers         American
# 1            1901     Love by the Light of the Moon         American
# 2            1901           The Martyred Presidents         American
# 3            1901  Terrible Teddy, the Grizzly King         American
# 4            1902            Jack and the Beanstalk         American
# ..            ...                               ...              ...
# 995          1930                    Playing Around         American
# 996          1930                           Raffles         American
# 997          1930             Reaching for the Moon         American
# 998          1930                   Recaptured Love         American
# 999          1930                       River's End         American
#
#                                Director  \
# 0                               Unknown
# 1                               Unknown
# 2                               Unknown
# 3                               Unknown
# 4    George S. Fleming, Edwin S. Porter
# ..                                  ...
# 995                        Mervyn LeRoy
# 996                  George Fitzmaurice
# 997                     Edmund Goulding
# 998                      John G. Adolfi
# 999                      Michael Curtiz
#
#                                                   Cast    Genre  \
# 0                                                  NaN  unknown
# 1                                                  NaN  unknown
# 2                                                  NaN  unknown
# 3                                                  NaN  unknown
# 4                                                  NaN  unknown
# ..                                                 ...      ...
# 995                        Alice White, Chester Morris    drama
# 996                         Ronald Colman, Kay Francis  mystery
# 997  Douglas Fairbanks, Edward Everett Horton, Bing...  musical
# 998                     Belle Bennett, Dorothy Burgess  musical
# 999                     Charles Bickford, Evalyn Knapp    drama
#
#                                              Wiki Page  \
# 0    https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1    https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2    https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3    https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4    https://en.wikipedia.org/wiki/Jack_and_the_Bea...
# ..                                                 ...
# 995       https://en.wikipedia.org/wiki/Playing_Around
# 996  https://en.wikipedia.org/wiki/Raffles_(1930_film)
# 997  https://en.wikipedia.org/wiki/Reaching_for_the...
# 998      https://en.wikipedia.org/wiki/Recaptured_Love
# 999  https://en.wikipedia.org/wiki/River%27s_End_(1...
#
#                                                   Plot
# 0    A bartender is working at a saloon, serving dr...
# 1    The moon, painted with a smiling face hangs ov...
# 2    The film, just over a minute long, is composed...
# 3    Lasting just 61 seconds and consisting of two ...
# 4    The earliest known adaptation of the classic f...
# ..                                                 ...
# 995  Alice White plays the part of a working class ...
# 996  Gentleman jewel thief A.J. Raffles (Ronald Col...
# 997  Wall Street wizard, Larry Day, new to the ways...
# 998  In this drama, a 50-year-old married man (play...
# 999  In remote northern Canada, Sergeant Conniston ...
#
# [1000 rows x 8 columns]

# %%
from datasets import Dataset


def map_dataset (batch):
    return tokenizer(
        batch ["Plot"],
        truncation=True,
        max_length=128,
        return_overflowing_tokens=True)


dataset = Dataset.from_pandas (df)

dataset = dataset.map(
    map_dataset,
    batched=True,
    batch_size=8,
    remove_columns=list(df.columns)
)

dataset = dataset.remove_columns (["overflow_to_sample_mapping"])
dataset = dataset.train_test_split (test_size=0.2)
dataset
# Out:
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 2390.63 examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask'],
#         num_rows: 2188
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask'],
#         num_rows: 548
#     })
# })

# %%
from transformers import DataCollatorForLanguageModeling

data_collator = DataCollatorForLanguageModeling (
    tokenizer=tokenizer,
    mlm=False
)
data_collator
# Out:
# DataCollatorForLanguageModeling(tokenizer=GPT2TokenizerFast(name_or_path='distilgpt2', vocab_size=50257, model_max_length=1024, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<|endoftext|>', 'eos_token': '<|endoftext|>', 'unk_token': '<|endoftext|>', 'pad_token': '<|endoftext|>'}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	50256: AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=True, special=True),
# }
# ), mlm=False, mlm_probability=0.15, mask_replace_prob=0.8, random_replace_prob=0.1, pad_to_multiple_of=None, tf_experimental_compile=False, return_tensors='pt', seed=None)

# %%
# !pip install --upgrade transformers
# Out:
# Requirement already satisfied: transformers in d:\gen ai\my first llm\.venv\lib\site-packages (4.51.3)
# Requirement already satisfied: filelock in d:\gen ai\my first llm\.venv\lib\site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in d:\gen ai\my first llm\.venv\lib\site-packages (from transformers) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\gen ai\my first llm\.venv\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in d:\gen ai\my first llm\.venv\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in d:\gen ai\my first llm\.venv\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in d:\gen ai\my first llm\.venv\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in d:\gen ai\my first llm\.venv\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in d:\gen ai\my first llm\.venv\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\gen ai\my first llm\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2024.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\gen ai\my first llm\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: colorama in d:\gen ai\my first llm\.venv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\gen ai\my first llm\.venv\lib\site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\gen ai\my first llm\.venv\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\gen ai\my first llm\.venv\lib\site-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\gen ai\my first llm\.venv\lib\site-packages (from requests->transformers) (2025.1.31)

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="./output/model",
    eval_strategy="epoch",  
    learning_rate=2e-5,
    weight_decay=0.01,
    num_train_epochs=10
)

trainer = Trainer(
    model=model,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"],
    args=training_args,
    data_collator=data_collator
)

trainer.train()
# Out:
# `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='2740' max='2740' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2740/2740 1:31:14, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>3.800214</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.896000</td>
#       <td>3.762239</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.896000</td>
#       <td>3.746954</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.672100</td>
#       <td>3.742980</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.672100</td>
#       <td>3.739705</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.573600</td>
#       <td>3.742474</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.573600</td>
#       <td>3.740049</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.513700</td>
#       <td>3.739237</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>3.513700</td>
#       <td>3.741376</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>3.472400</td>
#       <td>3.742020</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=2740, training_loss=3.6105993117729245, metrics={'train_runtime': 5476.57, 'train_samples_per_second': 3.995, 'train_steps_per_second': 0.5, 'total_flos': 714438392020992.0, 'train_loss': 3.6105993117729245, 'epoch': 10.0})

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("distilgpt2")
tokenizer.pad_token = tokenizer.eos_token
model = AutoModelForCausalLM. from_pretrained("./output/model/checkpoint-2740")


prompt = "A short film about a pilot who"
inputs = tokenizer(prompt, return_tensors="pt").to("cpu")

outputs = model.generate(
    inputs.input_ids,
    max_new_tokens=100,
    do_sample=True,
    top_k=50,
    top_p=0.95
)
output_string =tokenizer.batch_decode(outputs)

output_string
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ["A short film about a pilot who is trapped in an underground submarine, The Girl At Home (1970), a comedy about American military life and adventures, is produced and completed with director John Lautenberg. The film features several guests, as well as an American pilot, as well as a short film about America's war. Lautenberg is the chief of staff of a small company with a few employees. He is a sweetheart to his boss and, in addition to having a friendly reception with many other American and British men,"]
